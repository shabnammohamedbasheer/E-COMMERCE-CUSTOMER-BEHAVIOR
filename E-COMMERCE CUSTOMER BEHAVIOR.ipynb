# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ecommerce_customer_data.csv",index_col=0)

# %%
df
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 1        Female   23  Ahmedabad      Mobile                     60
# 2          Male   25    Kolkata      Tablet                     30
# 3          Male   32  Bangalore     Desktop                     37
# 4          Male   35      Delhi      Mobile                      7
# 5          Male   27  Bangalore      Tablet                     35
# ...         ...  ...        ...         ...                    ...
# 496        Male   24     Mumbai      Tablet                     40
# 497      Female   24  Hyderabad     Desktop                      8
# 498        Male   19       Pune     Desktop                     33
# 499        Male   28    Chennai     Desktop                      6
# 500      Female   31    Kolkata      Mobile                     16
#
#          Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases
# User_ID
# 1                        30                    1                0
# ...

# %%
df.shape
# Out:
# (500, 8)

# %%
df.dtypes
# Out:
# Gender                   object
# Age                       int64
# Location                 object
# Device_Type              object
# Product_Browsing_Time     int64
# Total_Pages_Viewed        int64
# Items_Added_to_Cart       int64
# Total_Purchases           int64
# dtype: object

# %%
df.isna().sum()
# Out:
# Gender                   0
# Age                      0
# Location                 0
# Device_Type              0
# Product_Browsing_Time    0
# Total_Pages_Viewed       0
# Items_Added_to_Cart      0
# Total_Purchases          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include="all").T
# Out:
#                        count unique      top freq    mean        std   min  \
# Gender                   500      2     Male  261     NaN        NaN   NaN
# Age                    500.0    NaN      NaN  NaN  26.276   5.114699  18.0
# Location                 500      8  Kolkata   71     NaN        NaN   NaN
# Device_Type              500      3   Mobile  178     NaN        NaN   NaN
# Product_Browsing_Time  500.0    NaN      NaN  NaN   30.74  15.934246   5.0
# Total_Pages_Viewed     500.0    NaN      NaN  NaN  27.182  13.071596   5.0
# Items_Added_to_Cart    500.0    NaN      NaN  NaN    5.15   3.203127   0.0
# Total_Purchases        500.0    NaN      NaN  NaN   2.464   1.740909   0.0
#
#                         25%   50%   75%   max
# Gender                  NaN   NaN   NaN   NaN
# Age                    22.0  26.0  31.0  35.0
# Location                NaN   NaN   NaN   NaN
# Device_Type             NaN   NaN   NaN   NaN
# Product_Browsing_Time  16.0  31.0  44.0  60.0
# ...

# %% [markdown]
# - most customers were male but not much variation
# - the average of customer was 26 , and the age grp was between 18 and 35
# - kolkata was the location with most customers
# - mainly shopping was done using mobile
# - people is spending an average of 30 mins on browsing and max of 1 hr
# - the avg pages viewed by the customer is 27
# - max products added to cart was 10 with an avg of 5 and min 2
# - max purchased products is 5 with an avg of 2 and min of 0

# %%
sns.countplot(data=df,x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=df,x="Location")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df,x="Device_Type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - most customers were male
# - people of age 21 and 29 was more customers
# - kolkata was having more customers followed by delhi
# - mobile was painly used by customers in e-commerce platform followed by tablet

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12956\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                             Age  Product_Browsing_Time  Total_Pages_Viewed  \
# Age                    1.000000              -0.055870            0.015823
# Product_Browsing_Time -0.055870               1.000000            0.027841
# Total_Pages_Viewed     0.015823               0.027841            1.000000
# Items_Added_to_Cart   -0.031033               0.017531            0.024570
# Total_Purchases       -0.042094              -0.023239            0.013630
#
#                        Items_Added_to_Cart  Total_Purchases
# Age                              -0.031033        -0.042094
# Product_Browsing_Time             0.017531        -0.023239
# ...

# %% [markdown]
# - none of the features are showing much correlation to each other

# %%
df
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 1        Female   23  Ahmedabad      Mobile                     60
# 2          Male   25    Kolkata      Tablet                     30
# 3          Male   32  Bangalore     Desktop                     37
# 4          Male   35      Delhi      Mobile                      7
# 5          Male   27  Bangalore      Tablet                     35
# ...         ...  ...        ...         ...                    ...
# 496        Male   24     Mumbai      Tablet                     40
# 497      Female   24  Hyderabad     Desktop                      8
# 498        Male   19       Pune     Desktop                     33
# 499        Male   28    Chennai     Desktop                      6
# 500      Female   31    Kolkata      Mobile                     16
#
#          Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases
# User_ID
# 1                        30                    1                0
# ...

# %%
sns.histplot(data=df,x="Total_Pages_Viewed")
# Out:
# <Axes: xlabel='Total_Pages_Viewed', ylabel='Count'>

# %%
sns.histplot(data=df,x="Product_Browsing_Time")
# Out:
# <Axes: xlabel='Product_Browsing_Time', ylabel='Count'>

# %%
df.loc[df["Gender"]=="Female",["Product_Browsing_Time"]].sum()
# Out:
# Product_Browsing_Time    7540
# dtype: int64

# %%
df.loc[df["Gender"]=="Male",["Product_Browsing_Time"]].sum()
# Out:
# Product_Browsing_Time    7830
# dtype: int64

# %%
df.loc[df["Gender"]=="Female",["Total_Purchases"]].sum()
# Out:
# Total_Purchases    544
# dtype: int64

# %%
df.loc[df["Gender"]=="Male",["Total_Purchases"]].sum()
# Out:
# Total_Purchases    688
# dtype: int64

# %% [markdown]
# - browsing time for male is more than female
# - total purchases also

# %%
plt.figure(figsize=(20,12))
sns.countplot(data=df,x="Location",hue="Gender")
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %% [markdown]
# - kolkata is the location with more number of customers where females are more
# - in chennai also female customers are more compared to male
# - other all places male customers are more

# %%
sns.countplot(data=df,x="Device_Type",hue="Gender")
# Out:
# <Axes: xlabel='Device_Type', ylabel='count'>

# %% [markdown]
# - mobile and tablets are the platforms used by men mostly for shopping
# - desktops are more used by women
# - mobile is the most used platform for e-commerce

# %%
sns.histplot(data=df,x="Age",hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df,x="Age",hue="Location")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df[df["Items_Added_to_Cart"]==df["Total_Purchases"]]
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 9          Male   33     Mumbai     Desktop                     21
# 23       Female   21     Mumbai      Tablet                     16
# 56       Female   32    Chennai      Tablet                     56
# 70       Female   20  Hyderabad      Mobile                     27
# 74       Female   29      Delhi      Mobile                     57
# 110      Female   32    Kolkata      Tablet                     31
# 125        Male   29    Kolkata     Desktop                     58
# 128      Female   31  Ahmedabad     Desktop                     28
# 180        Male   30      Delhi      Tablet                     14
# 201      Female   19     Mumbai      Tablet                     34
# 204      Female   21    Kolkata     Desktop                     56
# 232        Male   30      Delhi      Tablet                     47
# 242        Male   25  Bangalore      Tablet                     32
# ...

# %%
tot_pur=df[df["Items_Added_to_Cart"]!=df["Total_Purchases"]]
tot_pur
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 1        Female   23  Ahmedabad      Mobile                     60
# 2          Male   25    Kolkata      Tablet                     30
# 3          Male   32  Bangalore     Desktop                     37
# 4          Male   35      Delhi      Mobile                      7
# 5          Male   27  Bangalore      Tablet                     35
# ...         ...  ...        ...         ...                    ...
# 495        Male   31       Pune     Desktop                     32
# 497      Female   24  Hyderabad     Desktop                      8
# 498        Male   19       Pune     Desktop                     33
# 499        Male   28    Chennai     Desktop                      6
# 500      Female   31    Kolkata      Mobile                     16
#
#          Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases
# User_ID
# 1                        30                    1                0
# ...

# %% [markdown]
# - compared to the whole data we can see that very less customers are buying all the products that have been added to cart
# - more than 460 customers are not buying all the pdcts that have been added to cart

# %%
tot_pur.groupby("Items_Added_to_Cart")["Total_Purchases"].mean().reset_index()
# Out:
#     Items_Added_to_Cart  Total_Purchases
# 0                     0         3.027027
# 1                     1         2.547619
# 2                     2         2.212121
# 3                     3         2.391304
# 4                     4         2.500000
# 5                     5         1.625000
# 6                     6         1.750000
# 7                     7         2.780000
# 8                     8         2.557692
# 9                     9         2.739130
# 10                   10         2.326923

# %%
df["percentage_purchase"]=(tot_pur["Total_Purchases"]/tot_pur["Items_Added_to_Cart"])*100

# %%
df
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 1        Female   23  Ahmedabad      Mobile                     60
# 2          Male   25    Kolkata      Tablet                     30
# 3          Male   32  Bangalore     Desktop                     37
# 4          Male   35      Delhi      Mobile                      7
# 5          Male   27  Bangalore      Tablet                     35
# ...         ...  ...        ...         ...                    ...
# 496        Male   24     Mumbai      Tablet                     40
# 497      Female   24  Hyderabad     Desktop                      8
# 498        Male   19       Pune     Desktop                     33
# 499        Male   28    Chennai     Desktop                      6
# 500      Female   31    Kolkata      Mobile                     16
#
#          Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases  \
# User_ID
# 1                        30                    1                0
# ...

# %%
df["percentage_purchase"].value_counts().sort_values(ascending=False)
# Out:
# 0.000000      95
# inf           37
# 50.000000     33
# 25.000000     22
# 33.333333     17
# 20.000000     15
# 300.000000    14
# 22.222222     13
# 66.666667     13
# 400.000000    11
# 30.000000     11
# 40.000000     11
# 42.857143     10
# 71.428571     10
# 55.555556     10
# 62.500000     10
# 57.142857     10
# 125.000000    10
# 166.666667    10
# 200.000000     9
# 133.333333     9
# 44.444444      8
# 75.000000      8
# 28.571429      7
# 10.000000      6
# 80.000000      6
# 11.111111      6
# 12.500000      6
# 150.000000     6
# 16.666667      6
# 14.285714      5
# 250.000000     5
# 37.500000      5
# 60.000000      4
# 83.333333      3
# 500.000000     3
# Name: percentage_purchase, dtype: int64

# %% [markdown]
# - we can see the new column
# - it gets us the percentage of how much a customer have taken according to the items added to cart

# %%
df["percentage_purchase"].value_counts().sort_values(ascending=False).plot(kind="hist",bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# - most of the percentage of purchases fall between 0-40
# - it tells us more percentages
# - the total of 100% is less

# %%
Device = df.groupby('Device_Type')['Total_Purchases'].sum()
Device
# Out:
# Device_Type
# Desktop    381
# Mobile     451
# Tablet     400
# Name: Total_Purchases, dtype: int64

# %%
plt.figure(figsize=(10,8))
pie1 = Device.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Purcahse Through Device', fontsize =12)
pie1.legend(loc='upper right')
plt.show()

# %%
Brow = df.groupby('Device_Type')['Product_Browsing_Time'].sum()
Brow
# Out:
# Device_Type
# Desktop    4743
# Mobile     5459
# Tablet     5168
# Name: Product_Browsing_Time, dtype: int64

# %%
plt.figure(figsize=(10,8))
pie2 = Brow.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Device browsing time', fontsize =12)
pie2.legend(loc='upper right')
plt.show()

# %% [markdown]
# - Most of the purchase has done by Male.
# - Most of the purchase has done through Mobile
# - Mobile ha sused more time to browse through the site

# %%
loc=df.groupby("Location")["Total_Purchases"].sum()

# %%
loc
# Out:
# Location
# Ahmedabad    152
# Bangalore    147
# Chennai      143
# Delhi        191
# Hyderabad    138
# Kolkata      190
# Mumbai       145
# Pune         126
# Name: Total_Purchases, dtype: int64

# %%
plt.figure(figsize=(10,8))
pie3 = loc.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Location', fontsize =12)
pie3.legend(loc='upper right')
plt.show()

# %% [markdown]
# - delhi is having the highest percentage for shopping followed by kolkata

# %%
plt.figure(figsize=(10,8))
sns.barplot(df,x='Items_Added_to_Cart',y='Device_Type' ,hue = 'Total_Purchases',errorbar= None)
plt.show()

# %% [markdown]
# # categorising agewise

# %%
below_age=df[df["Age"]<21]
below_age
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 10       Female   18  Bangalore     Desktop                     12
# 32       Female   18    Kolkata      Tablet                     59
# 33       Female   18    Chennai      Mobile                     19
# 34       Female   20      Delhi      Tablet                     10
# 41       Female   19  Hyderabad      Mobile                     55
# ...         ...  ...        ...         ...                    ...
# 476        Male   18      Delhi      Mobile                     16
# 479        Male   20    Chennai     Desktop                     14
# 482        Male   19  Bangalore      Mobile                     46
# 492      Female   18    Kolkata     Desktop                     45
# 498        Male   19       Pune     Desktop                     33
#
#          Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases  \
# User_ID
# 10                       43                    2                5
# ...

# %%
b_age=below_age.groupby("Location")["Total_Purchases"].sum().sort_values(ascending=False)
b_age
# Out:
# Location
# Delhi        45
# Hyderabad    31
# Kolkata      28
# Chennai      27
# Mumbai       26
# Bangalore    24
# Ahmedabad    19
# Pune         17
# Name: Total_Purchases, dtype: int64

# %%
plt.figure(figsize=(10,8))
pie4 = b_age.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Location', fontsize =12)
pie4.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(below_age, hue= 'Device_Type', y= 'Product_Browsing_Time',x = 'Total_Purchases',errorbar= None )
plt.show()

# %% [markdown]
# ### Take aways

# %% [markdown]
# - Delhi is the most purcahsed location having age below 21
# - Mobile is used more and second is laptop is used for browsing and purchase of products by below aged customers.

# %%
mid_age = df[(df['Age'] >20) & (df['Age'] <30 )]
mid_age
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 1        Female   23  Ahmedabad      Mobile                     60
# 2          Male   25    Kolkata      Tablet                     30
# 5          Male   27  Bangalore      Tablet                     35
# 7        Female   22      Delhi      Mobile                     13
# 8        Female   25       Pune      Mobile                     42
# ...         ...  ...        ...         ...                    ...
# 493      Female   24       Pune     Desktop                     43
# 494        Male   29  Hyderabad      Mobile                     18
# 496        Male   24     Mumbai      Tablet                     40
# 497      Female   24  Hyderabad     Desktop                      8
# 499        Male   28    Chennai     Desktop                      6
#
#          Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases  \
# User_ID
# 1                        30                    1                0
# ...

# %%
M_age=mid_age .groupby('Location')['Total_Purchases'].sum()
M_age
# Out:
# Location
# Ahmedabad     79
# Bangalore     81
# Chennai       83
# Delhi         87
# Hyderabad     71
# Kolkata      103
# Mumbai        79
# Pune          67
# Name: Total_Purchases, dtype: int64

# %%
mid_age .groupby('Location')['Product_Browsing_Time'].sum()
# Out:
# Location
# Ahmedabad    1070
# Bangalore    1131
# Chennai       881
# Delhi        1135
# Hyderabad    1078
# Kolkata      1196
# Mumbai       1017
# Pune          968
# Name: Product_Browsing_Time, dtype: int64

# %%
plt.figure(figsize=(10,8))
pie5 = M_age.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Location', fontsize =12)
pie5.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(mid_age , hue= 'Device_Type', y= 'Product_Browsing_Time',x ='Total_Purchases',errorbar= None )
plt.show()

# %% [markdown]
# ###  Take aways

# %% [markdown]
# - Kolkata (15.8%)have more purcahse than other location
# - Tablet is used more and second is mobile is used for browsing and purchase of products by mid aged customers.

# %%
above_age = df[df['Age'] >29]
above_age
# Out:
#          Gender  Age   Location Device_Type  Product_Browsing_Time  \
# User_ID
# 3          Male   32  Bangalore     Desktop                     37
# 4          Male   35      Delhi      Mobile                      7
# 6          Male   31    Kolkata      Mobile                     34
# 9          Male   33     Mumbai     Desktop                     21
# 11       Female   30  Ahmedabad      Tablet                     31
# ...         ...  ...        ...         ...                    ...
# 484      Female   32    Kolkata     Desktop                     39
# 485        Male   31       Pune      Mobile                     12
# 487      Female   32  Hyderabad      Mobile                     50
# 495        Male   31       Pune     Desktop                     32
# 500      Female   31    Kolkata      Mobile                     16
#
#          Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases  \
# User_ID
# 3                        13                    5                0
# ...

# %%
Ab_age=above_age .groupby('Location')['Total_Purchases'].sum()
Ab_age
# Out:
# Location
# Ahmedabad    54
# Bangalore    42
# Chennai      33
# Delhi        59
# Hyderabad    36
# Kolkata      59
# Mumbai       40
# Pune         42
# Name: Total_Purchases, dtype: int64

# %%
plt.figure(figsize=(10,8))
pie6 = Ab_age.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Location', fontsize =12)
pie6.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(above_age , hue= 'Device_Type', y= 'Product_Browsing_Time',x ='Total_Purchases',errorbar= None )
plt.show()

# %% [markdown]
# ### Take away

# %% [markdown]
# - Delhi and Kolkata have same purcahse 16.2%
# - Tablet is used more for browsing and purchase of products by above aged customers.
